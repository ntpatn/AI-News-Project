# %%
import sys
import os
project_path = os.path.abspath(os.path.join(''))
sys.path.append(project_path)
con = os.environ.get("Connection_String")
print(project_path)
# Out:
# c:\Users\Lenovo\Desktop\AI-News-Project

# %%
from src.etl.bronze.extractors.data_structure_extract_strategy import DataExtractor

db_config = {
        "type": "db",
        "conn_str": con,
        "table": "news_features",
        "schema":"gold"
    }
with DataExtractor.get_extractor(cfg=db_config) as Extractor:
    df = Extractor.extractor()

df = df[["category","embedding"]]
df.head()
# Out:
#   category                                          embedding
# 0  general  [0.011863941326737404, 0.05410885810852051, 0....
# 1   sports  [0.056195661425590515, -0.0414116270840168, -0...
# 2  general  [-0.03449466824531555, 0.03250889480113983, -0...
# 3  general  [-0.038248155266046524, 0.0875236839056015, -0...
# 4  general  [-0.021108120679855347, 0.026924272999167442, ...

# %%
from src.etl.bronze.transform.data_format_strategy import (
    CsvToTempFormatter,
    DataFormatter,
)
csv_path = DataFormatter(
            CsvToTempFormatter(prefix="silver_dbt_combined_extract_")
        ).formatting(df)
print(csv_path)
# Out:
# c:\tmp\silver_dbt_combined_extract_jbzmcn0z.csv

# %%
from src.analysis.visualization.embedding_plot import generate_all_plots

generate_all_plots(csv_path,output_dir=f"{project_path}/report")
# Out:
# Generating UMAP...
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Generating PCA...
# ('c:\\Users\\Lenovo\\Desktop\\AI-News-Project/report/embedding_umap.png',
#  'c:\\Users\\Lenovo\\Desktop\\AI-News-Project/report/embedding_pca.png')
