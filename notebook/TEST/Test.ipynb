# %%
import sys
import os
project_path = os.path.abspath(os.path.join('../../'))
sys.path.append(project_path)
con = os.environ.get("Connection_String")

print(con)
# Out:
# postgresql://postgres:!NTpatn2549@localhost:5433/postgres

# %%
from src.etl.bronze.extractors.data_structure_extract_strategy import DataExtractor

db_config = {
        "type": "db",
        "conn_str": con,
        "table": "news_features",
        "schema":"gold"
    }
with DataExtractor.get_extractor(cfg=db_config) as Extractor:
    df = Extractor.extractor()

df.head(5)
# Out:
#                 sf_id                                                url  \
# 0  242165876118265875  https://www.npr.org/2025/10/29/g-s1-95710/nige...
# 1  243001474722832400  https://www.npr.org/2025/11/01/nx-s1-5590048/w...
# 2  241964976628047876  https://www.npr.org/2025/10/29/nx-s1-5588627/n...
# 3  243558383909609490  https://www.npr.org/2025/11/02/nx-s1-5587771/a...
# 4  243558383909609491  https://www.npr.org/2025/11/02/nx-s1-5293140/i...
#
#                                          title_clean  \
# 0  nigerian nobel winner wole soyinka says u s re...
# 1  week in politics snap updates trump s asia tri...
# 2  from horror to ibsen s hedda filmmaker nia dac...
# 3                are movie theaters worth it anymore
# 4  in her memoir margaret atwood reveals how she ...
#
#                                    description_clean        category  \
# 0  nigerian nobel winner wole soyinka says u s re...   art,lifestyle
# ...

# %%
df.describe()

# %%
df.info()

# %%
df["sf_id"].duplicated().any()
# Out:
# False

# %%
from src.function.index.sf_generator.database import SnowflakeDatabase
dsn = con
db = SnowflakeDatabase(dsn)
source_name = "bronze.currentsapi"
datacenter_id = 0
last_ts = db.get_last_timestamp(source_name, datacenter_id)

print("Last timestamp =", last_ts)
# Out:
# Last timestamp = 0
