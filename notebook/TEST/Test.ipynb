# %%
import sys
import os
project_path = os.path.abspath(os.path.join('../../'))
sys.path.append(project_path)
con = os.environ.get("Connection_String")

print(con)
# Out:
# postgresql://postgres:!NTpatn2549@localhost:5433/postgres

# %%
from src.etl.bronze.extractors.data_structure_extract_strategy import DataExtractor

db_config = {
        "type": "db",
        "conn_str": con,
        "table": "silver_dbt_combined",
        "schema":"silver"
    }
with DataExtractor.get_extractor(cfg=db_config) as Extractor:
    df = Extractor.extractor()

df.head(5)
# Out:
#                 sf_id source_system     source_name  \
# 0  242165876118265856   currentsapi  washingtonpost
# 1  242165876118265857   currentsapi            cnbc
# 2  242165876118265858   currentsapi         foxnews
# 3  242165876118265859   currentsapi            cnbc
# 4  242165876118265860   currentsapi         foxnews
#
#                              article_id        author  \
# 0  eb27e54e-0ced-4adf-8ba0-0c215ca47234  Andrew Jeong
# 1  4da1697b-d44a-423f-8c97-335c24d943a3    Anniek Bao
# 2  6a19dcca-6fdd-4e6f-9f62-bcbad10fe18a      Fox News
# 3  b779a798-82b5-4391-bf3f-98e7b2741230   Lim Hui Jie
# 4  3b1fbcae-ec0e-42a9-9b1a-d692ec445ef8      Fox News
#
#                                                title  \
# 0  4 killed in strike on another boat U.S. allege...
# 1  Trump cuts fentanyl tariffs on China to 10%, s...
# 2  Pakistan threatens to 'obliterate' Taliban aft...
# 3  South Korea's largest K-pop agency gains 644 m...
# ...

# %%
df.describe()
# Out:
#                      sf_id source_system  source_name        article_id  \
# count                 1254          1254         5100              4977
# unique                1254             3          139              4967
# top     242165876118265856   currentsapi  currentsapi  associated-press
# freq                     1          1110         2799                 5
# mean                   NaN           NaN          NaN               NaN
# min                    NaN           NaN          NaN               NaN
# 25%                    NaN           NaN          NaN               NaN
# 50%                    NaN           NaN          NaN               NaN
# 75%                    NaN           NaN          NaN               NaN
# max                    NaN           NaN          NaN               NaN
#
#          author                                 title  \
# count      5033                                  5088
# unique     1748                                  5039
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sf_id          1254 non-null   object
#  1   source_system  1254 non-null   object
#  2   source_name    5100 non-null   object
#  3   article_id     4977 non-null   object
#  4   author         5033 non-null   object
#  5   title          5088 non-null   object
#  6   description    5039 non-null   object
#  7   url            5100 non-null   object
#  8   image_url      4193 non-null   object
#  9   category       5079 non-null   object
#  10  language       5100 non-null   object
#  11  region         144 non-null    object
#  12  content        65 non-null     object
#  13  published_at   5100 non-null   datetime64[ns, UTC]
#  14  createdate     5100 non-null   datetime64[ns, UTC]
#  15  updatedate     240 non-null    datetime64[ns, UTC]
# ...

# %%
import uuid
df["uuid_silver"] = df.apply(lambda _: uuid.uuid4(), axis=1)

# %%
from src.function.index.sf_generator import SnowflakeGenerator
sf = SnowflakeGenerator(dsn=con, source_name="silver.dbt.combined")
df = sf.assign_ids_from_dataframe(df, ts_col="createdate", sf_col="sf_id")
if df["sf_id"].duplicated().any():
    raise print("Duplicate sf_id found after assignment.")

# %%
df.head(10)
# Out:
#                 sf_id source_system     source_name  \
# 0  242165876118265856   currentsapi  washingtonpost
# 1  242165876118265857   currentsapi            cnbc
# 2  242165876118265858   currentsapi         foxnews
# 3  242165876118265859   currentsapi            cnbc
# 4  242165876118265860   currentsapi         foxnews
# 5  242165876118265861   currentsapi         foxnews
# 6  242165876118265862   currentsapi            cnbc
# 7  242165876118265863   currentsapi         foxnews
# 8  242165876118265864   currentsapi         foxnews
# 9  241964976628047875   currentsapi        politico
#
#                              article_id        author  \
# 0  eb27e54e-0ced-4adf-8ba0-0c215ca47234  Andrew Jeong
# 1  4da1697b-d44a-423f-8c97-335c24d943a3    Anniek Bao
# 2  6a19dcca-6fdd-4e6f-9f62-bcbad10fe18a      Fox News
# 3  b779a798-82b5-4391-bf3f-98e7b2741230   Lim Hui Jie
# 4  3b1fbcae-ec0e-42a9-9b1a-d692ec445ef8      Fox News
# 5  5c35201c-3f1e-48d6-9128-aff946966094      Fox News
# ...

# %%
df = sf.assign_ids_from_dataframe(
    df,
    ts_col="createdate",   # คอลัมน์ datetime
    sf_col="sf_id",        # คอลัมน์ที่เก็บ Snowflake ID (ตอนนี้เป็น text ก็ได้)
)

# %%
df["sf_id"].duplicated().any()

# %%
from src.function.index.sf_generator.database import SnowflakeDatabase
dsn = con
db = SnowflakeDatabase(dsn)
source_name = "bronze.currentsapi"
datacenter_id = 0
last_ts = db.get_last_timestamp(source_name, datacenter_id)

print("Last timestamp =", last_ts)
